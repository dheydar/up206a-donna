# %%
import geopandas as gpd

# %%
county = gpd.read_file('../Week2Data/county_2012.shp')

# %%
county.shape
# Out:
# (58, 11)

# %% [markdown]
# The .shape output shows that there are 58 columns and 11 rows.

# %%
county.head()
# Out:
#                     slug              set           kind external_i  \
# 0    alameda-county-2012  Counties (2012)  County (2012)      06001
# 1     alpine-county-2012  Counties (2012)  County (2012)      06003
# 2     amador-county-2012  Counties (2012)  County (2012)      06005
# 3      butte-county-2012  Counties (2012)  County (2012)      06007
# 4  calaveras-county-2012  Counties (2012)  County (2012)      06009
#
#         name               display_na CountyFIPS StateFIPS   FIPS Name_1  \
# 0    Alameda    Alameda County (2012)        001        06  06001   None
# 1     Alpine     Alpine County (2012)        003        06  06003   None
# 2     Amador     Amador County (2012)        005        06  06005   None
# 3      Butte      Butte County (2012)        007        06  06007   None
# 4  Calaveras  Calaveras County (2012)        009        06  06009   None
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.31293 37.89733, -122.3108...
# ...

# %% [markdown]
# The .head() output shows a brief overview of the first 5 rows and columns of the dataset.

# %%
county.info
# Out:
# <bound method DataFrame.info of                            slug              set           kind external_i  \
# 0           alameda-county-2012  Counties (2012)  County (2012)      06001
# 1            alpine-county-2012  Counties (2012)  County (2012)      06003
# 2            amador-county-2012  Counties (2012)  County (2012)      06005
# 3             butte-county-2012  Counties (2012)  County (2012)      06007
# 4         calaveras-county-2012  Counties (2012)  County (2012)      06009
# 5            colusa-county-2012  Counties (2012)  County (2012)      06011
# 6      contra-costa-county-2012  Counties (2012)  County (2012)      06013
# 7         del-norte-county-2012  Counties (2012)  County (2012)      06015
# 8         el-dorado-county-2012  Counties (2012)  County (2012)      06017
# 9            fresno-county-2012  Counties (2012)  County (2012)      06019
# 10            glenn-county-2012  Counties (2012)  County (2012)      06021
# ...

# %% [markdown]
# The .info output shows a description/range of the dataset.

# %%
county.tail()
# Out:
#                     slug              set           kind external_i      name  \
# 53    tulare-county-2012  Counties (2012)  County (2012)      06107    Tulare
# 54  tuolumne-county-2012  Counties (2012)  County (2012)      06109  Tuolumne
# 55   ventura-county-2012  Counties (2012)  County (2012)      06111   Ventura
# 56      yolo-county-2012  Counties (2012)  County (2012)      06113      Yolo
# 57      yuba-county-2012  Counties (2012)  County (2012)      06115      Yuba
#
#                 display_na CountyFIPS StateFIPS   FIPS Name_1  \
# 53    Tulare County (2012)        107        06  06107   None
# 54  Tuolumne County (2012)        109        06  06109   None
# 55   Ventura County (2012)        111        06  06111   None
# 56      Yolo County (2012)        113        06  06113   None
# 57      Yuba County (2012)        115        06  06115   None
#
#                                              geometry
# 53  POLYGON ((-119.47503 36.39048, -119.47489 36.4...
# ...

# %% [markdown]
# The .tail() output shows the last 5 rows and columns of the dataset.

# %%
county.sample(5)
# Out:
#                        slug              set           kind external_i  \
# 22    mendocino-county-2012  Counties (2012)  County (2012)      06045
# 4     calaveras-county-2012  Counties (2012)  County (2012)      06009
# 56         yolo-county-2012  Counties (2012)  County (2012)      06113
# 55      ventura-county-2012  Counties (2012)  County (2012)      06111
# 42  santa-clara-county-2012  Counties (2012)  County (2012)      06085
#
#            name                 display_na CountyFIPS StateFIPS   FIPS Name_1  \
# 22    Mendocino    Mendocino County (2012)        045        06  06045   None
# 4     Calaveras    Calaveras County (2012)        009        06  06009   None
# 56         Yolo         Yolo County (2012)        113        06  06113   None
# 55      Ventura      Ventura County (2012)        111        06  06111   None
# 42  Santa Clara  Santa Clara County (2012)        085        06  06085   None
#
#                                              geometry
# ...

# %% [markdown]
# The .sample(5) shows 5 random rows and columns from the dataset.
